# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df =pd.read_csv('CarPrice_Assignment.csv')
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# 0           130        mpfi       3.47    2.68              9.0        111
# 1           130        mpfi       3.47    2.68              9.0        111
# 2           152        mpfi       2.68    3.47              9.0        154
# 3           109        mpfi       3.19    3.40             10.0        102
# 4           136        mpfi       3.19    3.40              8.0        115
# ..          ...         ...        ...     ...              ...        ...
# 200         141        mpfi       3.78    3.15              9.5        114
# 201         141        mpfi       3.78    3.15              8.7        160
# 202         173        mpfi       3.58    2.87              8.8        134
# 203         145         idi       3.01    3.40             23.0        106
# 204         141        mpfi       3.78    3.15              9.5        114
#
#      peakrpm citympg  highwaympg    price
# 0       5000      21          27  13495.0
# 1       5000      21          27  16500.0
# 2       5000      19          26  16500.0
# 3       5500      24          30  13950.0
# 4       5500      18          22  17450.0
# ..       ...     ...         ...      ...
# 200     5400      23          28  16845.0
# 201     5300      19          25  19045.0
# 202     5500      18          23  21485.0
# 203     4800      26          27  22470.0
# 204     5400      19          25  22625.0
#
# [205 rows x 26 columns]>

# %%
df.head(4)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
#
# [4 rows x 26 columns]

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
print(df.cylindernumber.unique())
print(df.doornumber.unique())
# Out:
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
# ['two' 'four']

# %%
pip install wordtodigits
# Out:
# Collecting wordtodigits
#   Downloading wordtodigits-1.0.2-py3-none-any.whl (3.8 kB)
# Installing collected packages: wordtodigits
# Successfully installed wordtodigits-1.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import wordtodigits

# %%
df.cylindernumber = df['cylindernumber'].apply(lambda x: int(wordtodigits.convert(x)))
df.doornumber = df['doornumber'].apply(lambda x: int(wordtodigits.convert(x)))
print(df.cylindernumber.unique())
print(df.doornumber.unique())
# Out:
# [ 4  6  5  3 12  2  8]
# [2 4]

# %%
table = df.groupby('CarName') 
table.first()
# Out:
#                           car_ID  symboling fueltype aspiration  doornumber  \
# CarName
# Nissan versa                  90          1      gas        std           2
# alfa-romero Quadrifoglio       3          1      gas        std           2
# alfa-romero giulia             1          3      gas        std           2
# alfa-romero stelvio            2          3      gas        std           2
# audi 100 ls                    4          2      gas        std           4
# ...                          ...        ...      ...        ...         ...
# volvo 246                    204         -1   diesel      turbo           4
# volvo 264gl                  199         -2      gas      turbo           4
# volvo diesel                 200         -1      gas      turbo           4
# vw dasher                    190          3      gas        std           2
# vw rabbit                    191          3      gas        std           2
#
#                               carbody drivewheel enginelocation  wheelbase  \
# CarName
# Nissan versa                    sedan        fwd          front       94.5
# alfa-romero Quadrifoglio    hatchback        rwd          front       94.5
# alfa-romero giulia        convertible        rwd          front       88.6
# alfa-romero stelvio       convertible        rwd          front       88.6
# audi 100 ls                     sedan        fwd          front       99.8
# ...                               ...        ...            ...        ...
# volvo 246                       sedan        rwd          front      109.1
# volvo 264gl                     sedan        rwd          front      104.3
# volvo diesel                    wagon        rwd          front      104.3
# vw dasher                 convertible        fwd          front       94.5
# vw rabbit                   hatchback        fwd          front       94.5
#
#                           carlength  ...  enginesize  fuelsystem  boreratio  \
# CarName                              ...
# Nissan versa                  165.3  ...          97        2bbl       3.15
# alfa-romero Quadrifoglio      171.2  ...         152        mpfi       2.68
# alfa-romero giulia            168.8  ...         130        mpfi       3.47
# alfa-romero stelvio           168.8  ...         130        mpfi       3.47
# audi 100 ls                   176.6  ...         109        mpfi       3.19
# ...                             ...  ...         ...         ...        ...
# volvo 246                     188.8  ...         145         idi       3.01
# volvo 264gl                   188.8  ...         130        mpfi       3.62
# volvo diesel                  188.8  ...         130        mpfi       3.62
# vw dasher                     159.3  ...         109        mpfi       3.19
# vw rabbit                     165.7  ...         109        mpfi       3.19
#
#                          stroke  compressionratio  horsepower peakrpm  \
# CarName
# Nissan versa               3.29               9.4          69    5200
# alfa-romero Quadrifoglio   3.47               9.0         154    5000
# alfa-romero giulia         2.68               9.0         111    5000
# alfa-romero stelvio        2.68               9.0         111    5000
# audi 100 ls                3.40              10.0         102    5500
# ...                         ...               ...         ...     ...
# volvo 246                  3.40              23.0         106    4800
# volvo 264gl                3.15               7.5         162    5100
# volvo diesel               3.15               7.5         162    5100
# vw dasher                  3.40               8.5          90    5500
# vw rabbit                  3.40               8.5          90    5500
#
#                           citympg  highwaympg    price
# CarName
# Nissan versa                   31          37   5499.0
# alfa-romero Quadrifoglio       19          26  16500.0
# alfa-romero giulia             21          27  13495.0
# alfa-romero stelvio            21          27  16500.0
# audi 100 ls                    24          30  13950.0
# ...                           ...         ...      ...
# volvo 246                      26          27  22470.0
# volvo 264gl                    17          22  18420.0
# volvo diesel                   17          22  18950.0
# vw dasher                      24          29  11595.0
# vw rabbit                      24          29   9980.0
#
# [147 rows x 25 columns]

# %%
plt.hist(df.price)
# Out:
# (array([83., 45., 35., 18.,  6.,  3.,  5.,  7.,  2.,  1.]),
#  array([ 5118. ,  9146.2, 13174.4, 17202.6, 21230.8, 25259. , 29287.2,
#         33315.4, 37343.6, 41371.8, 45400. ]),
#  <BarContainer object of 10 artists>)

# %%
print('Percentage of Cars having price less than 10000: ',
      (len(df[df.price < 10000])/df.shape[0])*100,'%')
print('Percentage of Cars having price more than 10000 but less than 20000: ',
      (len(df[(df.price > 10000) & (df.price < 20000 )])/df.shape[0])*100,'%')
print('Percentage of Cars having price more than 20000: ',
      (len(df[df.price > 20000])/df.shape[0])*100,'%')
# Out:
# Percentage of Cars having price less than 10000:  48.78048780487805 %
# Percentage of Cars having price more than 10000 but less than 20000:  38.53658536585366 %
# Percentage of Cars having price more than 20000:  12.682926829268293 %

# %%
def label_car(row):
    if row['price'] < 10000 :
        return 'Low End'
    if row['price'] > 10000 and row['price'] < 20000:
        return 'Mid End'
    if row['price'] > 20000:
        return 'High End'
    
df['End'] = df.apply(lambda row: label_car(row), axis=1)

# %%
df.drop(columns = ['CarName'], axis = 1, inplace = True)
df.head()
# Out:
#    car_ID  symboling fueltype aspiration  doornumber      carbody drivewheel  \
# 0       1          3      gas        std           2  convertible        rwd
# 1       2          3      gas        std           2  convertible        rwd
# 2       3          1      gas        std           2    hatchback        rwd
# 3       4          2      gas        std           4        sedan        fwd
# 4       5          2      gas        std           4        sedan        4wd
#
#   enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  stroke  \
# 0          front       88.6      168.8  ...        mpfi       3.47    2.68
# 1          front       88.6      168.8  ...        mpfi       3.47    2.68
# 2          front       94.5      171.2  ...        mpfi       2.68    3.47
# 3          front       99.8      176.6  ...        mpfi       3.19    3.40
# 4          front       99.4      176.6  ...        mpfi       3.19    3.40
#
#   compressionratio  horsepower  peakrpm citympg  highwaympg    price      End
# 0              9.0         111     5000      21          27  13495.0  Mid End
# 1              9.0         111     5000      21          27  16500.0  Mid End
# 2              9.0         154     5000      19          26  16500.0  Mid End
# 3             10.0         102     5500      24          30  13950.0  Mid End
# 4              8.0         115     5500      18          22  17450.0  Mid End
#
# [5 rows x 26 columns]

# %%
sns.set(style = 'darkgrid')
fig, axs = plt.subplots(3,3, figsize = (25,25))

sns.histplot(data=df, x="End", color="maroon", ax=axs[0, 0])
sns.histplot(data=df, x="aspiration", color="olive", ax=axs[0, 1])
sns.histplot(data=df, x="enginetype", color="gold", ax=axs[0, 2])
sns.histplot(data=df, x="carbody", color="teal", ax=axs[1, 0])
sns.histplot(data=df, x="drivewheel", color="green", ax=axs[1, 1])
sns.histplot(data=df, x="carbody", color="pink", ax=axs[1, 2])
sns.histplot(data=df, x="fueltype", color="orange", ax=axs[2, 0])
sns.histplot(data=df, x="fuelsystem", color="red", ax=axs[2, 1])
sns.histplot(data=df, x="enginelocation", color="blue", ax=axs[2, 2])
# Out:
# <Axes: xlabel='enginelocation', ylabel='Count'>

# %%
from sklearn.model_selection import train_test_split

# %%
dummy = pd.get_dummies(df, drop_first=True)
dummy.shape
x = dummy.drop(columns = ['price'], axis = 1)
y = dummy.price
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 100)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((164, 41), (41, 41), (164,), (41,))

# %%
corr = X_train.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
def correlation(data, threshold=None):
  
    col_corr = set()
    corr_mat = data.corr()
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if (abs(corr_mat.iloc[i,j]) > threshold):
                colname = corr_mat.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
correlated_features = correlation(data = X_train, threshold = 0.85)
set(correlated_features)
# Out:
# {'carlength',
#  'curbweight',
#  'drivewheel_rwd',
#  'enginesize',
#  'fuelsystem_4bbl',
#  'fuelsystem_idi',
#  'fueltype_gas',
#  'highwaympg'}

# %%
X_train.drop(labels = correlated_features, axis = 1, inplace = True)
X_test.drop(labels = correlated_features, axis = 1, inplace = True)
X_train.shape, X_test.shape
# Out:
# ((164, 33), (41, 33))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
scaled_X_train = scale.fit_transform(X_train)
scaled_X_test = scale.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200, random_state=100)
model_rf = rf.fit(scaled_X_train,y_train)

feature_names = dummy.columns
for name, importance in zip(feature_names, model_rf.feature_importances_):
    print(name, "=", importance)
# Out:
# car_ID = 0.013151078218089843
# symboling = 0.0018942041447351256
# doornumber = 0.0005364037606956694
# wheelbase = 0.012937009974641171
# carlength = 0.08739409939656699
# carwidth = 0.004688295246822361
# carheight = 0.2880814869480754
# curbweight = 0.08977682541810457
# cylindernumber = 0.004222926990541698
# enginesize = 0.004588445652289792
# boreratio = 0.18486602498013513
# stroke = 0.0035196509649443627
# compressionratio = 0.07444760722342382
# horsepower = 0.0012308828738200597
# peakrpm = 0.0001362646632612844
# citympg = 0.0016358574689054393
# highwaympg = 0.0005839367119866692
# price = 0.0003207971666317649
# fueltype_gas = 0.0012731565311610822
# aspiration_turbo = 0.001046658200459518
# carbody_hardtop = 0.00014720628257547117
# carbody_hatchback = 5.264769703279773e-05
# carbody_sedan = 0.0009315275567176811
# carbody_wagon = 9.889620477861836e-05
# drivewheel_fwd = 0.00016281754116942033
# drivewheel_rwd = 2.449789057262736e-05
# enginelocation_rear = 8.128147753957742e-05
# enginetype_dohcv = 3.2076554448341766e-06
# enginetype_l = 0.0010507695236927981
# enginetype_ohc = 0.00013111226133804147
# enginetype_ohcf = 0.0
# enginetype_ohcv = 0.12813625103118045
# enginetype_rotor = 0.09284817234266599

# %%
feat_importances = pd.Series(model_rf.feature_importances_, index=X_train.columns)
feat_importances.nlargest(4).plot(kind='barh', color=['blue', 'orange', 'green','red'])
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import ridge_regression
model_lr = LinearRegression()
model_la =Lasso()

# %%
model_lr.fit(scaled_X_train,y_train)
linear_score = model_lr.score(scaled_X_test,y_test)

# %%
random_forest_score = model_rf.score(scaled_X_test,y_test)

# %%
model_la.fit(scaled_X_train,y_train)
lasso_score = model_la.score(scaled_X_test,y_test)

# %%
Score = pd.DataFrame({'Model':['Linear Regression','Lasso','Random Forest'],
                      'Scores':[linear_score,lasso_score,random_forest_score]})
Score
# Out:
#                Model    Scores
# 0  Linear Regression  0.822073
# 1              Lasso  0.822706
# 2      Random Forest  0.886386

# %%
y_pred = model_rf.predict(scaled_X_test) 
plt.plot(y_test, y_pred, '.')
x = np.linspace(0, 330, 100)
y = x
plt.plot(x, y)
plt.show()
