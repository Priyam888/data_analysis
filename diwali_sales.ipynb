# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_diwali = pd.read_csv('Diwali Sales Data.csv',encoding = 'unicode_escape')
df_diwali
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df_diwali.fillna(0,inplace =True)
df_diwali
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df_diwali.shape
# Out:
# (11251, 15)

# %%
df_diwali.head(7)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# 1    Andhra Pradesh  Southern             Govt             Auto       3
# 2     Uttar Pradesh   Central       Automobile             Auto       3
# 3         Karnataka  Southern     Construction             Auto       2
# ...

# %%
df_diwali.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11251 non-null  float64
#  13  Status            11251 non-null  float64
#  14  unnamed1          11251 non-null  float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df_diwali.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9443.527902
# std    1.716125e+03     12.754122        0.493632      1.115047   5228.684037
# min    1.000001e+06     12.000000        0.000000      1.000000      0.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5440.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8108.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#         Status  unnamed1
# count  11251.0   11251.0
# mean       0.0       0.0
# std        0.0       0.0
# min        0.0       0.0
# 25%        0.0       0.0
# 50%        0.0       0.0
# 75%        0.0       0.0
# max        0.0       0.0

# %%
df_diwali.drop(['Status','unnamed1'],axis =1,inplace =True)
df_diwali
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_diwali.drop(['Status','unnamed1'],axis =1,inplace =True)
#       2 df_diwali
#
# File C:\Anaconda\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\Anaconda\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
pd.isnull(df_diwali).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df_diwali.shape
# Out:
# (11251, 13)

# %%
data_set =[['madhav',11],['Gopi',15],['Keshav',],['Lalita',16]]

df_diwali_test= pd.DataFrame(data_set,columns =['Name','Age'])

df_diwali_test
# Out:
#      Name   Age
# 0  madhav  11.0
# 1    Gopi  15.0
# 2  Keshav   NaN
# 3  Lalita  16.0

# %%
df_diwali_test.dropna(inplace =True)

# %%
df_diwali_test
# Out:
#      Name   Age
# 0  madhav  11.0
# 1    Gopi  15.0
# 3  Lalita  16.0

# %%
#change data  type
df_diwali['Amount'] = df_diwali['Amount'].astype('int')

# %%
df_diwali['Amount'].dtypes
# Out:
# dtype('int32')

# %%
df_diwali.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df_diwali.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9443.527598
# std    1.716125e+03     12.754122        0.493632      1.115047   5228.683337
# min    1.000001e+06     12.000000        0.000000      1.000000      0.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5440.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8108.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12671.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
at= sns.countplot(x ='Gender',data =df_diwali)

for bars in at.containers:
    at.bar_label(bars)

# %%
sales = df_diwali.groupby(['Gender'], as_index =False)['Amount'].sum().sort_values(by ='Amount',ascending=False)
sns.barplot(x ='Gender' , y='Amount', data =sales)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
AGE

# %%
at = sns.countplot(data = df_diwali, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    at.bar_label_label(bars)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 4
#       1 at = sns.countplot(data = df_diwali, x = 'Age Group', hue = 'Gender')
#       3 for bars in ax.containers:
# ----> 4     at.bar_label_label(bars)
#
# AttributeError: 'Axes' object has no attribute 'bar_label_label'

# %%
sales_age = df_diwali.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
STATE

# %%
sales_state = df_diwali.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
MARITAL STATUS

# %%
at = sns.countplot(data = df_diwali, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    at.bar_label(bars)

# %%
sales_state = df_diwali.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %%
sns.set(rc={'figure.figsize':(20,5)})
at = sns.countplot(data = df_diwali, x = 'Occupation')

for bars in ax.containers:
    at.bar_label(bars)

# %%
sales_state = df_diwali.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %%
sns.set(rc={'figure.figsize':(20,5)})
at = sns.countplot(data = df_diwali, x = 'Product_Category')

for bars in ax.containers:
    at.bar_label(bars)

# %%
sales_state = df_diwali.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %%
sales_state = df_diwali.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %%
fig1, ax1 = plt.subplots(figsize=(12,7))
df_diwali.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
